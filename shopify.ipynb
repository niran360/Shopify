# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv')
df.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
df.shape
# Out:
# (5000, 7)

# %% [markdown]
# **Question 1

# %%
import datasist as ds

# %%
ds.structdata.describe(df)
# Out:
# First five data points
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11
# Random five data points
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 4212      4213       26      740           528            3           cash
# 4532      4533       67      835           393            3           cash
# 1361      1362       38      846           570            3           cash
# ...

# %% [raw]
# After carrying out the **statistical Description** we can see that the MEAN $3145.128 is represented as the average order value (AOV) this is sometimes not very accurate since mean is not a robust statistic and can be biased.The maximum occurence is $704000, at the 50% mark (median) $704000 is so far from it, also we can observe a higher standard deviation $41282.539 this shows that the data is dispersed over a wide range of values.
#
#
# Visually representing the data for outliers.

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.scatter(df['shop_id'], df['order_amount'])
ax.set_xlabel('Shops Id')
ax.set_ylabel('Amount of ordered shoes')
plt.show()

# %% [markdown]
# Looking at the graph, its clear that we have outliers, so a better way to calculate the AOV considerint the outliers would be to use the median ($284)as its a better measure of central tendency.

# %% [raw]
# **Question 2

# %% [markdown]
# ###### How many orders were shipped by Speedy Express in total?

# %% [raw]
# SELECT COUNT (*) AS NumberOfOrders
#
# FROM Orders
#
# JOIN Shippers
#
# ON Shippers.ShipperID = Orders.ShipperID
#
# WHERE Shippers.ShipperName = 'Speedy Express'
#
# **Answer: 54

# %% [markdown]
# ###### What is the last name of the employee with the most orders?

# %% [raw]
# SELECT Employees.LastName, COUNT(*) AS NumberOfOrders
#
# FROM Orders
#
# JOIN Employees
#
# ON Orders.EmployeeID = Employees.EmployeeID
#
# GROUP BY Employees.LastName
#
# ORDER BY NumberOfOrders DESC
#
# LIMIT 1
#
# **Answer: Peacock	40

# %% [markdown]
# ###### What product was ordered the most by customers in Germany?

# %% [raw]
# <!-- First we get all the orders from germany -->
# SELECT Orders.OrderID,
#     Customers.Country
# FROM Orders
# JOIN Customers
#     ON Customers.CustomerID = Orders.CustomerID
# WHERE Customers.Country = 'Germany'
#
# <!-- Then we find out which of the product was ordered the most -->
#
# SELECT Customers.Country,
#
# OrderDetails.ProductID,
#
# SUM(OrderDetails.Quantity) AS "TotalOrdered"
#
# FROM Orders
#
# JOIN Customers
#
# ON Customers.CustomerID = Orders.CustomerID
#
# JOIN OrderDetails
#
# ON OrderDetails.OrderID = Orders.OrderID
#
# WHERE Customers.Country = 'Germany'
#
# GROUP BY OrderDetails.ProductID
#
# ORDER BY TotalOrdered DESC
#
# **Answer: The most ordered product has a product id of 40 at 160 orders
#
# <!-- Now we can get Which product was ordered the most by using the product id  -->
#
# SELECT Products.ProductName,
#
# SUM(OrderDetails.Quantity) AS "TotalOrdered"
#
# FROM Orders
#
# JOIN Customers
#
# ON Customers.CustomerID = Orders.CustomerID
#
# JOIN OrderDetails
#
# ON OrderDetails.OrderID = Orders.OrderID
#
# JOIN Products
#
# ON Products.ProductID = OrderDetails.ProductID
#
# WHERE Customers.Country = 'Germany'
#
# GROUP BY OrderDetails.ProductID
#
# ORDER BY TotalOrdered DESC
#
# **Answer: The most ordered product is Boston Crab Meat with 160 orders
